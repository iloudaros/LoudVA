# %% [markdown]
# # Plotting the Performance Test Results
#
# We use this notebook to i.plot the results of the [performance_profiling](https://github.com/iloudaros/LoudVA/blob/main/ansible/performance_profiling.yaml) play, that collects results for different Jetson Configurations.
# 296542.36s --> 3.4322032407 days

# %%
import ihelper as i

device = 'agx-xavier-00'
measurement_code = 'Representative'
measurement_dir = f'/home/louduser/LoudVA/measurements/archive/{measurement_code}/{device}/measurements'

# %% [markdown]
# ## Plotting the results of the GPU Frequency Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/performance/freqs", 0, 1, "Concurrency", "Inferences/Second", "Inferences/Second vs Concurrency (Jetson AGX Xavier)")

# %% [markdown]
# #### Energy Consumption

# %%
i.plot(f"{measurement_dir}/energy/freqs", 0, 4, "Concurrency", "Energy (J)", "Energy vs Concurrency (Jetson AGX Xavier)")
i.plot(
    folder_path=f"{measurement_dir}/energy/freqs",
    row_number_x=3,
    row_number_y=4,
    row_name_x='Throughput (Inference/sec)',
    row_name_y='Energy (J)',
    title='Throughput vs Energy with Latency Pareto Optimization (Jetson AGX Xavier)',
    connect_points=False,
    label_column=0,
    label_points=True,
    row_number_z=2,
    pareto_boundary=True,
    maximize_x=True,
    maximize_y=False,
    maximize_z=False
)

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/performance/freqs", 0, 9, "Concurrency", "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/freqs", 0, 10, "Concurrency", "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/freqs", 0, 12, "Concurrency", "p99 Latency in ms", "p99 Latency vs Concurrency")

# %% [markdown]
# #### Energy Consumption

# %%
i.plot(f"{measurement_dir}/energy/freqs", 2, 4, "Avg Latency (s)", "Energy (J)", "Energy vs Latency (Jetson AGX Xavier)", connect_points=False)

# %% [markdown]
# ### Latency vs Inferences per second

# %%
i.plot(f"{measurement_dir}/energy/freqs", 3, 2, "Throughput (Inferences/Second)", "Avg Latency (s)", "Latency vs Throughput (Jetson AGX Xavier)", connect_points=False)

# %% [markdown]
# ## Plotting the results of the Power Mode Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/performance/modes", 0, 1, "Concurrency", "Inferences/Second", "Inferences/Second vs Concurrency")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 i.plot(f"{measurement_dir}/performance/modes", 0, 1, "Concurrency", "Inferences/Second", "Inferences/Second vs Concurrency")
#
# File ~/LoudVA/plots/ihelper.py:56, in plot(folder_path, row_number_x, row_number_y, row_name_x, row_name_y, title, label_column, connect_points, label_points, offset, pareto_boundary, maximize_x, maximize_y, row_number_z, maximize_z, debug_mode)
#      54 def plot(folder_path, row_number_x, row_number_y, row_name_x, row_name_y, title, label_column=None, connect_points=True, label_points=False, offset=(0.1, -0.2), pareto_boundary=False, maximize_x=False, maximize_y=False, row_number_z=None, maximize_z=False, debug_mode=False):
#      55     # Get filenames and filter only the ones containing a digit before the extension
# ---> 56     filenames = os.listdir(folder_path)
#      57     filenames = [f for f in filenames if extract_frequency_from_filename(f) is not None]
#      58     filenames = sorted(filenames, key=lambda x: extract_frequency_from_filename(x), reverse=True)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/louduser/LoudVA/measurements/archive/Representative/agx-xavier-00/measurements/performance/modes'

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/performance/modes", 0, 9, "Concurrency", "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/modes", 0, 10, "Concurrency", "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/modes", 0, 12, "Concurrency", "p99 Latency in ms", "p99 Latency vs Concurrency")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 i.plot(f"{measurement_dir}/performance/modes", 0, 9, "Concurrency", "p50 Latency in ms", "p50 Latency vs Concurrency")
#       2 i.plot(f"{measurement_dir}/performance/modes", 0, 10, "Concurrency", "p90 Latency in ms", "p90 Latency vs Concurrency")
#       3 i.plot(f"{measurement_dir}/performance/modes", 0, 12, "Concurrency", "p99 Latency in ms", "p99 Latency vs Concurrency")
#
# File ~/LoudVA/plots/ihelper.py:7, in plot(folder_path, row_number_x, row_number_y, row_name_x, row_name_y, title, connect_points)
#       5 def plot(folder_path, row_number_x, row_number_y, row_name_x, row_name_y, title, connect_points=True):
#       6   # Get filenames sorted by the highest integer in their names (descending order)
# ----> 7   filenames = os.listdir(folder_path)
#       8   filenames = sorted(filenames, key=lambda x : int(x.split("_")[-1].split(".")[0]) if x.endswith('.csv') else 0, reverse=True)
#      10   colors = plt.colormaps['tab20c']
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/louduser/LoudVA/measurements/archive/Representative/agx-xavier-00/measurements/performance/modes'
