# %% [markdown]
# # Plotting the Performance Test Results
#
# We use this notebook to plot the results of the [performance_profiling](https://github.com/iloudaros/LoudVA/blob/main/ansible/performance_profiling.yaml) play, that collects results for different Jetson Configurations.

# %%
import ihelper as i

device = 'LoudJetson0'
measurement_dir = f'/home/louduser/LoudVA/measurements/{device}/measurements/performance'

# %% [markdown]
# ## Plotting the results of the GPU Frequency Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/freqs", 1, "Inferences/Second", "Inferences/Second vs Concurrency")
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plot(f"{measurement_dir}/freqs", 1, "Inferences/Second", "Inferences/Second vs Concurrency")
#
# Cell In[21], line 18, in plot(folder_path, row_number, row_name, title)
#      16 with open(filepath, 'r') as csvfile:
#      17   reader = csv.reader(csvfile, delimiter=',')
# ---> 18   next(reader)
#      19   # Read data and sort it by the first column
#      20   data = sorted(reader, key=lambda row: float(row[0]))
#
# StopIteration:

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/freqs", 9, "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/freqs", 10, "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/freqs", 12, "p99 Latency in ms", "p99 Latency vs Concurrency")
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot(f"{measurement_dir}/freqs", 9, "p50 Latency in ms", "p50 Latency vs Concurrency")
#       2 plot(f"{measurement_dir}/freqs", 10, "p90 Latency in ms", "p90 Latency vs Concurrency")
#       3 plot(f"{measurement_dir}/freqs", 12, "p99 Latency in ms", "p99 Latency vs Concurrency")
#
# Cell In[2], line 18, in plot(folder_path, row_number, row_name, title)
#      16 with open(filepath, 'r') as csvfile:
#      17   reader = csv.reader(csvfile, delimiter=',')
# ---> 18   next(reader)  # Skip the header row
#      20   # Read data and sort it by the first column
#      21   data = sorted(reader, key=lambda row: float(row[0]))
#
# StopIteration:

# %% [markdown]
# ## Plotting the results of the Power Mode Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/modes", 1, "Inferences/Second", "Inferences/Second vs Concurrency")

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/modes", 9, "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/modes", 10, "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/modes", 12, "p99 Latency in ms", "p99 Latency vs Concurrency")
