# %% [markdown]
# # Plotting the Performance Test Results
#
# We use this notebook to i.plot the results of the [performance_profiling](https://github.com/iloudaros/LoudVA/blob/main/ansible/performance_profiling.yaml) play, that collects results for different Jetson Configurations.
# 296542.36s --> 3.4322032407 days

# %%
import iPlotter as i

device = 'agx-xavier-00'
measurement_code = 'Representative'
measurement_dir = f'../measurements/archive/{measurement_code}/{device}/measurements'

# %% [markdown]
# ## Plotting the results of the GPU Frequency Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/performance/freqs", 0, 1, "Concurrency", "Inferences/Second", "Inferences/Second vs Concurrency (Jetson AGX Xavier)")

# %% [markdown]
# #### Energy Consumption

# %%
i.plot(f"{measurement_dir}/energy/freqs", 0, 4, "Concurrency", "Energy (J)", "Energy vs Concurrency (Jetson AGX Xavier)")
i.plot(
    folder_paths=f"{measurement_dir}/energy/freqs",
    row_number_x=3,
    row_number_y=4,
    row_name_x='Throughput (Inference/sec)',
    row_name_y='Energy (J)',
    title='Throughput vs Energy with Latency Pareto Optimization (Jetson AGX Xavier)',
    connect_points=False,
    label_column=0,
    label_points=True,
    row_number_z=2,
    pareto_boundary=True,
    maximize_x=True,
    maximize_y=False,
    maximize_z=False,
    distrust_file_paths=f"{measurement_dir}/retried_freqs.txt",
    distrust_threshold=0,
    debug_mode=False,
    export_file_path=f"{measurement_dir}/{device}_filtered_freqs.csv"
)

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/performance/freqs", 0, 9, "Concurrency", "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/freqs", 0, 10, "Concurrency", "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/freqs", 0, 12, "Concurrency", "p99 Latency in ms", "p99 Latency vs Concurrency")

# %% [markdown]
# #### Energy Consumption

# %%
i.plot(
    folder_paths=f"{measurement_dir}/energy/freqs",
    row_number_x=2,
    row_number_y=4,
    row_name_x="Avg Latency (s)",
    row_name_y='Energy (J)',
    title='Latency vs Energy with Throughput Pareto Optimization (Jetson AGX Xavier)',
    connect_points=False,
    label_column=0,
    label_points=True,
    row_number_z=3,
    pareto_boundary=True,
    maximize_x=False,
    maximize_y=False,
    maximize_z=True,
    offset=(0,0),
    distrust_file_paths=f"{measurement_dir}/retried_freqs.txt",
    distrust_threshold=0,
    )

# %%
# Energy vs Throughput
i.plot(
    folder_paths=f"{measurement_dir}/energy/freqs",
    row_number_x=2,
    row_number_y=4,
    row_name_x="Throughput (Inference/sec)",
    row_name_y='Energy (J)',
    title='Throughput vs Energy with Latency (Jetson AGX Xavier)',
    connect_points=False,
    label_column=0,
    label_points=True,
    row_number_z=3,
    pareto_boundary=False,
    maximize_x=True,
    maximize_y=False,
    maximize_z=False,
    offset=(0,0),
    distrust_file_paths=f"{measurement_dir}/retried_freqs.txt",
    distrust_threshold=0,
    )

# %% [markdown]
# ### Latency vs Inferences per second

# %%
i.plot(f"{measurement_dir}/energy/freqs", 3, 2, "Throughput (Inferences/Second)", "Avg Latency (s)", "Latency vs Throughput (Jetson AGX Xavier)", connect_points=False)

# %% [markdown]
# ## Plotting the results of the Power Mode Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/performance/modes", 0, 1, "Concurrency", "Inferences/Second", "Inferences/Second vs Concurrency")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 i.plot(f"{measurement_dir}/performance/modes", 0, 1, "Concurrency", "Inferences/Second", "Inferences/Second vs Concurrency")
#
# File ~/LoudVA/plots/iPlotter.py:73, in plot(folder_paths, row_number_x, row_number_y, row_name_x, row_name_y, title, label_column, connect_points, label_points, offset, pareto_boundary, maximize_x, maximize_y, row_number_z, row_name_z, maximize_z, debug_mode, distrust_file_paths, distrust_threshold, export_file_path, directory_labels, filter_only)
#      70 single_directory = len(folder_paths) == 1
#      72 for folder_path, dirname in zip(folder_paths, directory_labels):
# ---> 73     filenames = sorted([f for f in os.listdir(folder_path) if extract_frequency_from_filename(f) is not None],
#      74                        key=lambda x: extract_frequency_from_filename(x), reverse=True)
#      75     all_filenames.extend([(f, dirname) for f in filenames])
#      76     frequencies_by_folder[dirname] = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '../measurements/archive/Representative/agx-xavier-00/measurements/performance/modes'

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/performance/modes", 0, 9, "Concurrency", "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/modes", 0, 10, "Concurrency", "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/modes", 0, 12, "Concurrency", "p99 Latency in ms", "p99 Latency vs Concurrency")
