# %% [markdown]
# # Plotting the Performance Test Results
#
# We use this notebook to i.plot the results of the [performance_profiling](https://github.com/iloudaros/LoudVA/blob/main/ansible/performance_profiling.yaml) play, that collects results for different Jetson Configurations.
# 296542.36s --> 3.4322032407 days

# %%
import ihelper as i

device = 'agx-xavier-00'
measurement_code = 'Representative'
measurement_dir = f'/home/louduser/LoudVA/measurements/archive/{measurement_code}/{device}/measurements'

# %% [markdown]
# ## Plotting the results of the GPU Frequency Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/performance/freqs", 1, "Inferences/Second", "Inferences/Second vs Concurrency")
i.plot(f"{measurement_dir}/energy/freqs", 3, "Energy (J)", "Energy vs Concurrency")

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/performance/freqs", 9, "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/freqs", 10, "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/performance/freqs", 12, "p99 Latency in ms", "p99 Latency vs Concurrency")

# %% [markdown]
# ## Plotting the results of the Power Mode Test

# %% [markdown]
# ### Inferences per second

# %%
i.plot(f"{measurement_dir}/modes", 1, "Inferences/Second", "Inferences/Second vs Concurrency")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 i.plot(f"{measurement_dir}/modes", 1, "Inferences/Second", "Inferences/Second vs Concurrency")
#
# File ~/LoudVA/plots/ihelper.py:7, in plot(folder_path, row_number, row_name, title)
#       5 def plot(folder_path, row_number, row_name, title):
#       6   # Get filenames sorted by the highest integer in their names (descending order)
# ----> 7   filenames = os.listdir(folder_path)
#       8   filenames = sorted(filenames, key=lambda x : int(x.split("_")[-1].split(".")[0]) if x.endswith('.csv') else 0, reverse=True)
#      10   colors = plt.colormaps['tab20c']
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/louduser/LoudVA/measurements/archive/Representative/agx-xavier-00/measurements/modes'

# %% [markdown]
# ### Latency

# %%
i.plot(f"{measurement_dir}/modes", 9, "p50 Latency in ms", "p50 Latency vs Concurrency")
i.plot(f"{measurement_dir}/modes", 10, "p90 Latency in ms", "p90 Latency vs Concurrency")
i.plot(f"{measurement_dir}/modes", 12, "p99 Latency in ms", "p99 Latency vs Concurrency")
